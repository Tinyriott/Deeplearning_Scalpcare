# %%
import pandas as pd

# %%
df = pd.read_csv("./values_counts_photo-location_modified-column-name.csv")

# %%
df
# Out:
#                                            Filename  미세각질  피지과다  모낭사이홍반  \
# 0      0013_A2LEBJJDE00060O_1606550825417_3_TH.json     0     0       0
# 1      0177_A2LEBJJDE00152B_1604650530904_6_BH.json     0     0       0
# 2      0335_A2LEBJJDE00013X_1602916465540_6_BH.json     0     0       0
# 3      0335_A2LEBJJDE000542_1605676381132_4_LH.json     0     0       0
# 4      0425_A2LEBJJDE00079P_1605793927978_5_RH.json     0     0       0
# ...                                             ...   ...   ...     ...
# 71591  7670_A1LCAIHDH000126_1607569556516_3_TH.json     0     2       0
# 71592  7851_A2LEBJJDE00074P_1608359740234_2_TH.json     0     1       1
# 71593  7985_A1LCAIHDH00011D_1608459833021_3_TH.json     0     1       0
# 71594  9244_A2LEBJJDE00154W_1607590387532_5_RH.json     0     1       0
# 71595  9527_A2LEBJJDE00110E_1606732870059_3_TH.json     0     1       0
#
#        모낭홍반/농포  비듬  탈모 Photo_Location
# 0            0   0   0             TH
# ...

# %%
df[(df["미세각질"] == 0) & (df["피지과다"] != 0)].count()
# Out:
# Filename          57002
# 미세각질              57002
# 피지과다              57002
# 모낭사이홍반            57002
# 모낭홍반/농포           57002
# 비듬                57002
# 탈모                57002
# Photo_Location    57002
# dtype: int64

# %%
df["피지과다"][df["피지과다"] != 0]
# Out:
# 534      2
# 536      1
# 537      1
# 538      3
# 539      2
#         ..
# 71591    2
# 71592    1
# 71593    1
# 71594    1
# 71595    1
# Name: 피지과다, Length: 58770, dtype: int64

# %%
len(df[(df["미세각질"] == 0) & (df["피지과다"] != 0)])
# Out:
# 57002

# %%
len(df[df["피지과다"] != 0])
# Out:
# 58770

# %%
len(df[(df["미세각질"] == 0) & (df["피지과다"] != 0)])/len(df[df["피지과다"] != 0])
# Out:
# 0.9699166241279564

# %%
len(df[(df["미세각질"] == 0) & (df["피지과다"] != 0)])/len(df[df["미세각질"] == 0])
# Out:
# 0.9648763478172554

# %%
len(df[(df["미세각질"] != 0) & (df["피지과다"] == 0)])/len(df[df["피지과다"] == 0])
# Out:
# 0.8382192421643536

# %%
len(df[(df["미세각질"] != 0) & (df["피지과다"] == 0)])/len(df[df["미세각질"] != 0])
# Out:
# 0.8587746625129803

# %%
df[(df["미세각질"] == 0) & (df["피지과다"] == 0)]
# Out:
#                                            Filename  미세각질  피지과다  모낭사이홍반  \
# 0      0013_A2LEBJJDE00060O_1606550825417_3_TH.json     0     0       0
# 1      0177_A2LEBJJDE00152B_1604650530904_6_BH.json     0     0       0
# 2      0335_A2LEBJJDE00013X_1602916465540_6_BH.json     0     0       0
# 3      0335_A2LEBJJDE000542_1605676381132_4_LH.json     0     0       0
# 4      0425_A2LEBJJDE00079P_1605793927978_5_RH.json     0     0       0
# ...                                             ...   ...   ...     ...
# 70105  4810_A2LEBJJDE00177Y_1607586245169_3_TH.json     0     0       0
# 70211  5619_A2LEBJJDE00002B_1606721953583_3_TH.json     0     0       0
# 70277  7229_A2LEBJJDE00142H_1606545064726_3_TH.json     0     0       0
# 70330  8000_A2LEBJJDE000956_1607762026280_2_TH.json     0     0       0
# 70412  8896_A2LEBJJDE001807_1606456669246_4_LH.json     0     0       0
#
#        모낭홍반/농포  비듬  탈모 Photo_Location
# 0            0   0   0             TH
# ...

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['미세각질'] != 0, df['피지과다'] == 0)

chi2_stat, p_value, _, _ = chi2_contingency(contingency_table)

print(f"- 미세각질 증상이 있고, 피지과다는 양호 -\nchi2 통계량 : {chi2_stat}\np-value : {p_value}")
# Out:
# - 미세각질 증상이 있고, 피지과다는 양호 -
# chi2 통계량 : 47650.266239731965
# p-value : 0.0

# %%
contingency_table
# Out:
# 피지과다   False  True
# 미세각질
# False  57002   2075
# True    1768  10751

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['미세각질'] == 0, df['피지과다'] != 0)

chi2_stat, p_value, _, _ = chi2_contingency(contingency_table)

print(f"- 미세각질이 양호, 피지과다가 증상이 있음 -\nchi2 통계량 : {chi2_stat}\np-value : {p_value}")
# Out:
# - 미세각질이 양호, 피지과다가 증상이 있음 -
# chi2 통계량 : 47650.26623973197
# p-value : 0.0

# %%
contingency_table
# Out:
# 피지과다   False  True
# 미세각질
# False  10751   1768
# True    2075  57002

# %%
o = df['피지과다'][df["피지과다"] == 1].count()
tw = df['피지과다'][df["피지과다"] == 2].count()
th = df['피지과다'][df["피지과다"] == 3].count()

# %%
print(o, tw, th)
# Out:
# 29433 25617 3720

# %%
df[(df["모낭사이홍반"] != 0)]
# Out:
#                                            Filename  미세각질  피지과다  모낭사이홍반  \
# 534    0013_A2LEBJJDE00060O_1602911366731_5_RH.json     0     2       1
# 535    0013_A2LEBJJDE00060O_1603096385510_2_TH.json     2     0       1
# 536    0013_A2LEBJJDE00060O_1603096790519_4_LH.json     0     1       1
# 537    0013_A2LEBJJDE00060O_1603096790519_6_BH.json     0     1       1
# 538    0013_A2LEBJJDE00060O_1603257373184_2_TH.json     0     3       1
# ...                                             ...   ...   ...     ...
# 71577  4970_A1LCAIHDH00010K_1608451612533_3_TH.json     0     1       1
# 71578  4970_A1LCAIHDH00010K_1608455283197_3_TH.json     0     1       1
# 71579  4970_A1LCAIHDH00010K_1608455660056_3_TH.json     0     1       1
# 71580  4970_A1LCAIHDH00010K_1608524873531_3_TH.json     0     1       1
# 71592  7851_A2LEBJJDE00074P_1608359740234_2_TH.json     0     1       1
#
#        모낭홍반/농포  비듬  탈모 Photo_Location
# 534          0   2   0             RH
# ...
